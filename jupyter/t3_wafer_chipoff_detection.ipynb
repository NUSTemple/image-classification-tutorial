# %% [markdown]
# ### Import Libary

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import cv2 
import os
from PIL import Image

# %% [markdown]
# ### Load Image

# %%
image_path = "../data/refine"

image_files = [f for f in os.listdir(image_path) if f.endswith('.png')]

image_file = image_files[0]
filename = os.path.join(image_path, image_file)
im = Image.open(filename)
im2arr = np.array(im) # im2arr.shape: height x width x channel
Image.fromarray(im2arr)
# Out:
# <PIL.Image.Image image mode=L size=3217x1024 at 0x7FD579DD8C50>

# %% [markdown]
# ### Image Analytics
